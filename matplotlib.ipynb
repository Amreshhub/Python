# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
a =[10,20,30,35,40,4]
plt.plot(range(len(a)),a)#line plot
plt.show()
x1 = range(10)
y1 = pd.Series(x1) ** 2
y2 = pd.Series(x1) ** 3
plt.plot(x1, y1, x1, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x7dfe5c0>,
#  <matplotlib.lines.Line2D at 0x7dfe748>]

# %%
a =[10,20,30,35,40,4]
plt.figure(figsize =(16,5))

plt.show()
x1 = range(10)
y1 = pd.Series(x1) ** 2
y2 = pd.Series(x1) ** 3
plt.plot(x1, y1, x1, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x6835f98>,
#  <matplotlib.lines.Line2D at 0x68353c8>]

# %%
df = pd.read_csv('titanic_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name  gender      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  $211.34        B5        S    2    NaN
# 1      2  113781  $151.55   C22 C26        S   11    NaN
# 2      2  113781  $151.55   C22 C26        S  NaN    NaN
# 3      2  113781  $151.55   C22 C26        S  NaN  135.0
# 4      2  113781  $151.55   C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
r = df.gender.value_counts()
plt.figure(figsize = (16,5))

plt.subplot(1,2, 1)
print(r)
print(r.plot(kind ='bar'))
plt.subplot(1,2, 2)
plt.bar(r.index,r.values)

plt.show()
# Out:
# male      843
# female    466
# Name: gender, dtype: int64
# AxesSubplot(0.125,0.125;0.352273x0.755)

# %%
x = pd.Series(range(10))
y1 = x *2
y2 = x *4
plt.plot(x, y1, label ='s1')
plt.plot(x, y2, label ='s2')
plt.legend()

plt.title('titel')
plt.xlabel('X')
plt.ylabel('Y')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
x = pd.Series(range(10))
y =(x ) **2

plt.plot(x,y)
plt.stem(x,y)
plt.savefig('graph.png')
plt.show()
# Out:
# C:\Users\AMRESH SINGH\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
x = pd.Series(range(10))
y =(x ) **2

plt.plot(x,y)
plt.axvline(5,linewidth = 1, c = 'g')

plt.show()

# %%
plt.figure(figsize = (16,6))
_#,bins,_ = 
plt.hist(df.age,bins =30)
plt.show()

# %%
a = [10,20,15,5]
plt.pie(a,explode = [0,0,2,0.1])

# %%
dff = pd.DataFrame({2001:[10,20,30,23,40], 2009: [40,20,10,5,10], 2019: [40,20,10,5,10]})
print(dff)

dff.plot(kind = 'bar', stacked = True)

plt.show()
# Out:
#    2001  2009  2019
# 0    10    40    40
# 1    20    20    20
# 2    30    10    10
# 3    23     5     5
# 4    40    10    10
